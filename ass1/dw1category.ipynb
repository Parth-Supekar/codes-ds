# %%
#ASSIGNMENT 1 | PARTH SUPEKAR 20CO130
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load dataset
df=pd.read_csv("graduation_rate.csv")

# %%
df.head()
# Out:
#    ACT composite score  SAT total score parental level of education  \
# 0                   22             1625                 high school
# 1                   29             2090          associate's degree
# 2                   30             2188           bachelor's degree
# 3                   33             2151          associate's degree
# 4                   29             2050          associate's degree
#
#    parental income  high school gpa  college gpa  years to graduate
# 0            40999              3.0          3.1                  7
# 1            75817              4.0          3.4                  5
# 2            82888              4.0          3.9                  3
# 3            93518              4.0          3.7                  5
# 4            79153              4.0          3.4                  6

# %% [markdown]
# ###DATA PREPROCESSING

# %%
df.isnull().any()
# Out:
# ACT composite score            False
# SAT total score                False
# parental level of education    False
# parental income                False
# high school gpa                False
# college gpa                    False
# years to graduate              False
# dtype: bool

# %%
df.describe()
# Out:
#        ACT composite score  SAT total score  parental income  high school gpa  \
# count          1000.000000      1000.000000       1000.00000      1000.000000
# mean             28.607000      1999.906000      67377.85200         3.707400
# std               2.774211       145.078361      18827.33105         0.287381
# min              20.000000      1598.000000      18906.00000         2.800000
# 25%              27.000000      1898.000000      54269.75000         3.500000
# 50%              28.500000      2000.000000      67842.50000         3.800000
# 75%              31.000000      2099.000000      80465.50000         4.000000
# max              36.000000      2385.000000     124470.00000         4.000000
#
#        college gpa  years to graduate
# count  1000.000000        1000.000000
# mean      3.376500           4.982000
# std       0.237179           1.414099
# min       2.600000           3.000000
# 25%       3.200000           4.000000
# ...

# %%
df.isna().sum()
# Out:
# ACT composite score            0
# SAT total score                0
# parental level of education    0
# parental income                0
# high school gpa                0
# college gpa                    0
# years to graduate              0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 7)

# %%
df1=df.drop('high school gpa',axis=1)

# %%
df1.shape
# Out:
# (1000, 6)

# %%
df1.info
# Out:
# <bound method DataFrame.info of      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  college gpa  years to graduate
# ...

# %%
df1.isnull().sum()
# Out:
# ACT composite score            0
# SAT total score                0
# parental level of education    0
# parental income                0
# college gpa                    0
# years to graduate              0
# dtype: int64

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  college gpa  years to graduate
# ...

# %%
df2=df1.drop(['college gpa','years to graduate'],axis=1)
df2.head()
# Out:
#    ACT composite score  SAT total score parental level of education  \
# 0                   22             1625                 high school
# 1                   29             2090          associate's degree
# 2                   30             2188           bachelor's degree
# 3                   33             2151          associate's degree
# 4                   29             2050          associate's degree
#
#    parental income
# 0            40999
# 1            75817
# 2            82888
# 3            93518
# 4            79153

# %%
df2.dtypes
# Out:
# ACT composite score             int64
# SAT total score                 int64
# parental level of education    object
# parental income                 int64
# dtype: object

# %%
pd.get_dummies(df2,dtype='int')
# Out:
#      ACT composite score  SAT total score  parental income  \
# 0                     22             1625            40999
# 1                     29             2090            75817
# 2                     30             2188            82888
# 3                     33             2151            93518
# 4                     29             2050            79153
# ..                   ...              ...              ...
# 995                   32             2234            30658
# 996                   27             1930            59443
# 997                   32             2117            94415
# 998                   32             2034            31713
# 999                   34             2268            93832
#
#      parental level of education_associate's degree  \
# 0                                                 0
# 1                                                 1
# 2                                                 0
# ...
